# %% [markdown]
# # Final Project: Classification with Python

# %% [markdown]
# ## Table of Contents
#
# . Instructions
#
# . Bout the Data
#
# . Importing Data
#
# . Data Preprocessing
#
# . One Hot Encoding
#
# . Train and Test Data Split
#
# . Train Logistic Regression, KNN, Decision Tree, SVM, and Linear Regression models and return their appropiate accuracy scores

# %% [markdown]
# ## Instructions
#
# we will use some of the algorithms taught in course, specifically:
#
# 1. Linear Regression
# 2. KNN
# 3. Decision Tress
# 4. Logistic Regression
# 5. SVM
#
# We will evaluate our models using:
# 1. Accuracy Score
# 2. Jaccard Index
# 3. F1-Score
# 4. LogLoss
# 5. Mean Absolute Error
# 6. Mean Squared Error
# 7. R2-Score

# %% [markdown]
# ### Importing the required libraries

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillUp/labs/ML-FinalAssignment/Weather_Data.csv'
w_df = pd.read_csv(url)
w_df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# ## Data Pre-processing
#
# #### One Hot Encoding
#
# First, we need to perform one hot encoding to convert categorical variables to binary variables.

# %%
df_sydney_processed = pd.get_dummies(data=w_df, columns=['RainToday', 'WindDir9am', 'WindGustDir', 'WindDir3pm'])

# %% [markdown]
# Next, we replace the values of the 'RainTomorrow' column changing them from a categorical column to a binary column. We do not use the get_dummies method because we could end up with two columns for RainTomorrow and we do not want, since 'RainTomorrow' is our target.

# %%
df_sydney_processed.replace(['No', 'Yes'], [0,1], inplace=True)

# %% [markdown]
# ## Training Data and Test Data
#
# Now, we set our 'features' or x values and our Y or target variable

# %%
df_sydney_processed.drop('Date',axis=1,inplace=True)

# %%
df_sydney_processed = df_sydney_processed.astype(float)

# %%
features = df_sydney_processed.drop(columns='RainTomorrow', axis=1)
Y = df_sydney_processed['RainTomorrow']

# %% [markdown]
# ## Linear Regression
#
# #### Q1) Use the train_test_split function to split the features and Y dataframes with test_size of 0.2 and the random_state set to 10.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(features, Y, test_size=0.2, random_state=10)

# %% [markdown]
# #### Q2) Create and train a Linear Regression model called LinearReg using the training data (x_train, y_train).

# %%
LinearReg = LinearRegression()

# Entrenar el modelo con los datos de entrenamiento
LinearReg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Q3) Now use the predict method on the testing data (x_test) and save it to the array predictions

# %%
# Supongamos que ya tienes un modelo entrenado llamado 'model'
# y datos de prueba 'x_test'

predictions = LinearReg.predict(X_test)

# %% [markdown]
# ### Q4) Using the predictions and the y_test dataframe calculate the value of each metric using appropriate function.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

LinearRegression_MAE = mean_absolute_error(Y_test, predictions)
LinearRegression_MSE = mean_squared_error(Y_test, predictions)
LinearRegression_R2 = r2_score(Y_test, predictions)

print(f'LinearRegression_MAE: {LinearRegression_MAE}')
print(f'LinearRegression_MSE: {LinearRegression_MSE}')
print(f'LinearRegression_R2: {LinearRegression_R2}')
# Out:
# LinearRegression_MAE: 0.2563176099420381
# LinearRegression_MSE: 0.11572058282746585
# LinearRegression_R2: 0.4271321073623009

# %% [markdown]
# ## Q5) Show the MAE, MSE and R2 in a tabulat format using dataframe for the linear model.

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calcular MAE, MSE y R2
mae = mean_absolute_error(Y_test, predictions)
mse = mean_squared_error(Y_test, predictions)
r2 = r2_score(Y_test, predictions)

# Crear un diccionario con los valores
report = {
    'MAE': [mae],
    'MSE': [mse],
    'R2': [r2]
}

# Crear un DataFrame a partir del diccionario
df_metrics = pd.DataFrame(report)

# Mostrar el DataFrame
print(df_metrics)
# Out:
#         MAE       MSE        R2
# 0  0.256318  0.115721  0.427132

# %% [markdown]
# ## Q6) Create and train a KNN model called KNN using the training data (x_train, y_train) with the neighbors parameter set to 4

# %%
from sklearn.neighbors import KNeighborsClassifier

# Crear una instancia del modelo KNN con 4 vecinos
KNN = KNeighborsClassifier(n_neighbors=4)

# Entrenar el modelo con los datos de entrenamiento
KNN.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %% [markdown]
# ## Q7) Now use the predict method on the testing data (x_test) and save it to the array predictions.

# %%
predictions = KNN.predict(X_test)

# %% [markdown]
# ## Q8) Using the predictions and the y_test dataframe calculate the value for each numeric using appropriate function.

# %%
from sklearn.metrics import accuracy_score, jaccard_score, f1_score

# Calcular el Accuracy Score
KNN_Accuracy_Score = accuracy_score(Y_test, predictions)

# Calcular el Jaccard Index (coeficiente de similitud de Jaccard)
KNN_JaccardIndex = jaccard_score(Y_test, predictions)

# Calcular el F1 Score
KNN_F1_Score = f1_score(Y_test, predictions)

# Imprimir los resultados
print("KNN Accuracy Score:", KNN_Accuracy_Score)
print("KNN Jaccard Index:", KNN_JaccardIndex)
print("KNN F1 Score:", KNN_F1_Score)
# Out:
# KNN Accuracy Score: 0.8183206106870229
# KNN Jaccard Index: 0.4251207729468599
# KNN F1 Score: 0.5966101694915255

# %% [markdown]
# ## Q9) Create and train a Decision Tree model called Tree using the training data (x_train, y_train)

# %%
from sklearn.tree import DecisionTreeClassifier

# Crear un objeto de modelo de árbol de decisión
Tree = DecisionTreeClassifier()

# Entrenar el modelo de árbol de decisión con los datos de entrenamiento
Tree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Q10) Now use the predict method on the testing data (x_test) and save it to the array predictions.

# %%
predictions = Tree.predict(X_test)

# %% [markdown]
# ## Q11) Using the predictions and the y_test dataframe calculate the value for each metric using the apptopriate function.

# %%
from sklearn.metrics import accuracy_score, jaccard_score, f1_score

# Calcular el Accuracy Score
Tree_Accuracy_Score = accuracy_score(Y_test, predictions)

# Calcular el Jaccard Index (coeficiente de similitud de Jaccard)
Tree_JaccardIndex = jaccard_score(Y_test, predictions)

# Calcular el F1 Score
Tree_F1_Score = f1_score(Y_test, predictions)

# Imprimir los resultados
print("Tree Accuracy Score:", Tree_Accuracy_Score)
print("Tree Jaccard Index:", Tree_JaccardIndex)
print("Tree F1 Score:", Tree_F1_Score)
# Out:
# Tree Accuracy Score: 0.7480916030534351
# Tree Jaccard Index: 0.3888888888888889
# Tree F1 Score: 0.5599999999999999

# %% [markdown]
# ## Q12) Use the train_test_split function to split the features and Y dataframes with a test_size of 2.0 and the random_state set to 1.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(features, Y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Q13) Create and train a LogisticRegression model called LR using the training data (x_train, y_train) with the solver parameter set to liblinear

# %%
from sklearn.linear_model import LogisticRegression

# Crear una instancia del modelo de regresión logística con solver="liblinear"
LR = LogisticRegression(solver="liblinear")

# Entrenar el modelo con los datos de entrenamiento
LR.fit(X_train, Y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %% [markdown]
# ## Q14) Now, use the predict and predict_proba methods on the testing data (x_test) and save it as 2 arrays predictions and predict_proba.

# %%
from sklearn.ensemble import RandomForestClassifier
# Suponiendo que ya tienes un modelo entrenado llamado 'model'
predictions = LR.predict(X_test)  # Predicciones de clases
Y_proba = LR.predict_proba(X_test)  # Probabilidades de clases

# 'predictions' contendrá las clases predichas para cada ejemplo en x_test
# 'predict_proba' contendrá las probabilidades de cada clase para cada ejemplo en x_test

# %% [markdown]
# ## Q15) Using the predictions, predict_proba and the y_test dataframe calculate the value for each metric using the appropriate function.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Supongamos que 'y_pred' son tus predicciones (etiquetas de clase) y 'y_proba' son las probabilidades de predicción.
# También asumiremos que 'y_test' es el conjunto de datos de prueba.

# Calcular la precisión
accuracy = accuracy_score(Y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Calcular la precisión
precision = precision_score(Y_test, predictions)
print(f'Precision: {precision:.2f}')

# Calcular la recuperación
recall = recall_score(Y_test, predictions)
print(f'Recall: {recall:.2f}')

# Calcular el F1-score
f1 = f1_score(Y_test, predictions)
print(f'F1 Score: {f1:.2f}')

# Calcular el área bajo la curva ROC (AUC-ROC) si tienes probabilidades de predicción
roc_auc = roc_auc_score(Y_test, Y_proba)
print(f'AUC-ROC: {roc_auc:.2f}')
# Out:
# Accuracy: 0.84
# Precision: 0.76
# Recall: 0.61
# F1 Score: 0.68
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 23
#      20 print(f'F1 Score: {f1:.2f}')
#      22 # Calcular el área bajo la curva ROC (AUC-ROC) si tienes probabilidades de predicción
# ---> 23 roc_auc = roc_auc_score(Y_test, Y_proba)
#      24 print(f'AUC-ROC: {roc_auc:.2f}')
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:569, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     567     labels = np.unique(y_true)
#     568     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 569     return _average_binary_score(
#     570         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     571         y_true,
#     572         y_score,
#     573         average,
# ...

# %% [markdown]
# ## Q16) Create and train a SVM model called SVM using the training data (x_train, y_train)

# %%
# Create an SVM model with a linear kernel
SVM = svm.SVC(kernel='linear')

# Train the SVM model using the training data
SVM.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = SVM.predict(X_test)

# %% [markdown]
# ## Q17) Now use the predict method on the testing data (x_test) and save it to the array predictions.

# %%
model = LinearRegression()

model.fit(X_train, Y_train)

predictions = SVM.predict(X_test)

# %% [markdown]
# ## Q18) Using the predictions and the y_test dataframe calculate the value for each metric using appropiate function.

# %%
from sklearn.metrics import accuracy_score, jaccard_score, f1_score

# Calcular el Accuracy Score
SVM_Accuracy_Score = accuracy_score(Y_test, predictions)

# Calcular el Jaccard Index (coeficiente de similitud de Jaccard)
SVM_JaccardIndex = jaccard_score(Y_test, predictions)

# Calcular el F1 Score
SVM_F1_Score = f1_score(Y_test, predictions)

# Imprimir los resultados
print("SVM Accuracy Score:", Tree_Accuracy_Score)
print("SVM Jaccard Index:", Tree_JaccardIndex)
print("SVM F1 Score:", Tree_F1_Score)
# Out:
# SVM Accuracy Score: 0.7480916030534351
# SVM Jaccard Index: 0.3888888888888889
# SVM F1 Score: 0.5599999999999999

# %% [markdown]
# ## Q19) Show the accuracy, jaccard Index, F1-score and logloss in a tabular format using data frame for all of the above models.
#
# * LogLoss is only for logistic regression Model

# %%
mport pandas as pd

# Supongamos que tienes los resultados de tus modelos en las siguientes variables
model_names = ['SVM', 'LR', 'Tree', 'KNN']
accuracies = [, 0.74, 0.72, 0.81]
jaccard_indices = [0.38, 0.68, 0.62, 0.73]
f1_scores = [0.55, 0.75, 0.70, 0.78]
logloss_values = [0.5, 0.6, 0.7, 0.4]  # Agrega los valores reales de LogLoss aquí

# Crear un diccionario con los datos
Report = {
    'Model': model_names,
    'Accuracy': accuracies,
    'Jaccard Index': jaccard_indices,
    'F1-score': f1_scores,
    'LogLoss': logloss_values
}

# Crear un DataFrame
df = pd.DataFrame(Report)

# Mostrar el DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 5
#       1 import pandas as pd
#       3 data = {
#       4     'Model': ['Model 1', 'Model 2'],
# ----> 5     'Accuracy': [model1_accuracy, model2_accuracy],
#       6     'Jaccard Index': [model1_jaccard, model2_jaccard],
#       7     'F1-score': [model1_f1, model2_f1],
#       8     'Logloss': [model1_logloss, model2_logloss]
#       9 }
#      11 df = pd.DataFrame(data)
#      12 print(df)
#
# NameError: name 'model1_accuracy' is not defined
